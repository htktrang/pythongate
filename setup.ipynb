# %% [markdown]
# Check python version (should be 3.11 for opengate 10.0b7)

# %%
# !py --version
# Out:
# Python 3.11.8

# %% [markdown]
# Upgrade pip

# %%
# !py -m pip install --upgrade pip

# %% [markdown]
# Install opengate

# %%
# !py -m pip install opengate-core
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached colored-2.2.4-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 2.2 MB/s eta 0:00:07
#     --------------------------------------- 0.2/15.5 MB 3.1 MB/s eta 0:00:05
# ...

# %%
# !py -m pip install --pre opengate
# Out:
# ...
#   Using cached opengate-10.0b7-py3-none-any.whl.metadata (4.0 kB)
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------------- ------------- 41.0/60.9 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/162.6 kB ? eta -:--:--
#      --------------------------------- ---- 143.4/162.6 kB 4.3 MB/s eta 0:00:01
#      -------------------------------------- 162.6/162.6 kB 3.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
# ...

# %% [markdown]
# Run a test at https://github.com/OpenGATE/opengate/tree/master/opengate/tests/src to download gea4 dataset
